# %%
import pandas as pd

raw_data = pd.read_csv("data/train.csv")
raw_data
# Out:
#         TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0                     3       F                1            1
# 1                     4       M                1            3
# 2                     3       M                1            3
# 3                     2       M                1            3
# 4                     3       F                1            1
# ...                 ...     ...              ...          ...
# 207386                5       F                1            3
# 207387                2       F                1            3
# 207388                3       F                1            1
# 207389                2       F                1            1
# 207390                3       M                1            4
#
#         TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ESCOLA  TP_ENSINO  IN_TREINEIRO  \
# 0                      1                2          2        1.0             0
# 1                      1                2          2        1.0             0
# 2                      1                2          2        1.0             0
# 3                      1                2          2        1.0             0
# 4                      1                2          2        1.0             0
# ...                  ...              ...        ...        ...           ...
# 207386                 1                2          2        1.0             0
# 207387                 1                2          2        1.0             0
# 207388                 1                2          3        1.0             0
# 207389                 1                2          3        1.0             0
# 207390                 1                2          2        1.0             0
#
#         CO_MUNICIPIO_ESC  ... Q020  Q021 Q022  Q023  Q024  Q025       ID  \
# 0              4322707.0  ...    A     A    E     A     B     B  2464336
# 1              3303500.0  ...    A     B    B     A     A     A  1983774
# 2              2408102.0  ...    A     A    E     A     B     B  1440554
# 3              2306405.0  ...    A     A    B     A     A     A  2522015
# 4              3520509.0  ...    A     A    D     A     A     B  3274277
# ...                  ...  ...  ...   ...  ...   ...   ...   ...      ...
# 207386         5201405.0  ...    A     A    B     A     A     B  2195991
# 207387         2313302.0  ...    B     A    C     A     A     B   331822
# 207388         3522703.0  ...    A     B    E     B     D     B  1092831
# 207389         4106902.0  ...    A     B    C     A     C     B  3184302
# 207390         3529005.0  ...    A     A    D     B     C     B  2183559
#
#             MF  NU_ANO CONCEITO
# 0       608.46    2020        C
# 1       362.88    2020        E
# 2       681.82    2020        C
# 3       462.20    2020        E
# 4       506.72    2020        D
# ...        ...     ...      ...
# 207386  439.46    2020        E
# 207387  625.36    2020        C
# 207388  680.02    2020        C
# 207389  785.96    2020        B
# 207390  538.40    2020        D
#
# [207391 rows x 77 columns]

# %%
# Separa as colunas que são object
object_columns = raw_data.select_dtypes(include=['object']).columns
display(raw_data[object_columns])

# Separando os dados de respostas e gabaritos
answers = raw_data[[col for col in object_columns if "TX" in col]]
data_to_encode = raw_data[[col for col in object_columns if "TX" not in col]]


# Encode categorical features
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in data_to_encode.columns:
    data_to_encode[col] = le.fit_transform(data_to_encode[col])

data_to_encode
# Out:
#        TP_SEXO      NO_MUNICIPIO_ESC SG_UF_ESC    NO_MUNICIPIO_PROVA  \
# 0            F             Vera Cruz        RS     Santa Cruz do Sul
# 1            M           Nova Igua�u        RJ           Nova Igua�u
# 2            M                 Natal        RN                 Natal
# 3            M             Itapipoca        CE             Itapipoca
# 4            F            Indaiatuba        SP            Indaiatuba
# ...        ...                   ...       ...                   ...
# 207386       F  Aparecida de Goi�nia        GO  Aparecida de Goi�nia
# 207387       F                  Tau�        CE                  Tau�
# 207388       F              It�polis        SP              It�polis
# 207389       F              Curitiba        PR              Curitiba
# 207390       M               Mar�lia        SP               Mar�lia
#
#        SG_UF_PROVA                                TX_RESPOSTAS_CN  \
# 0               RS  CAEBACDBECEABABBEAEBCDCCDABCDABCBADCCCCDBCBCD
# 1               RJ  DCABEDEABCCDDECEEBDCADCDAABEBEBDDEBBCABDBCCAE
# 2               RN  ABAACDCBCEDEACDCECCAABDBAAECCBABABBCBDAAACBAE
# 3               CE  EEDDCEEBADDABDEEEABAAEDCECCEECECDCBDABEEBBACE
# 4               SP  DBDCEDEEDCABCADADCDEEABCBCDAEBECABDEBBDCCDBEA
# ...            ...                                            ...
# 207386          GO  BDABDEEECBDEEECCAAACEECEDCAAECEDCDBEEEAADBCBA
# 207387          CE  ECCDDCABDEDBAEBCCDCDBAAAECAEBDBBBCAADAADBECCD
# 207388          SP  BABDDAECEEBADABEDDACCCBCBABCEABBDCACCCBDBBBCD
# 207389          PR  EDECABEBADCCEBCDCDBBBEECACDAEBACBCBECDBBBADAD
# 207390          SP  EADCAEEBEDEEBBAACCCACEBCABBEAACBEAECCCCDCEDCB
#
#                                       TX_RESPOSTAS_CH  \
# 0       EDDAEDCBEACBCDAEEBBAADCDBEEEEEEEEEEEEEEEEEEEE
# 1       EBAEDDECEAABDBCCABBBAEADBEEBDEABEACCAEEDBAEBA
# 2       BAECDEBBBEEDEBBAEAEABECCCAEABCEABAEABAABADDDA
# 3       BBEBCABCDBCBDBCBADBBECEDCABDBABAEBCBAABDACABB
# 4       BDCBDABBAAEAECDCEBEBECBAADBAADACEDCDBBECADBAA
# ...                                               ...
# 207386  ADBBBCABCEACBCEADBDDDCBAABDECD*CDAABAEBCD.CBA
# 207387  BBBBAEEABAABBECDBAAEAEBAACAEA.EDDEBEDCBDCBEDC
# 207388  EBAAAAEBEAEBBBBAECABABADBBBECDCABCBDDEBACCBAD
# 207389  BEECCAEABADBCAECAAEEDDEBBBADBCBADEEBBBADCCBBA
# 207390  DDBDEAECEBAABDCDACBEAAEDAEACCCCABADCDEBCEAAAC
#
#                                           TX_RESPOSTAS_LC  \
# 0       ACCAE99999DEEAEDAADCDCEBBDEADDDAAEDBDEAEECEEEE...
# 1       99999AAAADDCBDEEABAEBADAEDBDEADBCECBEEAACBAAAC...
# 2       CABDC99999BDCDEADEBEBECBDABBCECCBCCACCBDDAEABD...
# 3       99999AADDDCDCCDBDDABAABACCECBBBDBBAACBEAAECBAE...
# 4       ABADC99999CDABDDEEDDECADABBBDDDBEEAECBEBABCDEC...
# ...                                                   ...
# 207386  99999AACAAADBABEDECDBCDABABDDADCCECAEBBAACADCB...
# 207387  AACCA99999BDEADDCEDCBBEDCDDDABCADEEACECCCEDDCD...
# 207388  ACADB99999DEBACBADACDEEABCCAECDDDDABDAECCBDCCC...
# 207389  ABBAC99999CDADEADEBCDEBDCEDBEDDBBCADCDEAADABAA...
# 207390  CCABA99999ADEADCBDABEBAACBEADDADADBCEABCCBCECE...
#
#                                       TX_RESPOSTAS_MT  \
# 0       DCCDEABCDDCCDECDCBCCEAADDBEECDAAEDEADDCBDEACD
# 1       EDBDEECABDEDCCBCCAEDABDEBABEDCBACCDAEBADBDAEB
# 2       BDCBEBCEAEBDEDBDBCADAAEDBBEBBBDCCCDDCDEBABDBB
# 3       BEDCEDAAEDDEDEBBEADBECCBEDCDAEEDDACBCCEEBDDDC
# 4       EADECBDDCDDCAEEADBCCAADCDCBDBCACBDEABACDABCDB
# ...                                               ...
# 207386  CAEECCBECCCDBEBEDCBACBEACDBACACDBACACBADCEDCC
# 207387  CACABCBCEBACDCDECDBACBEEBCDABBCDCEABCABEDBCCD
# 207388  DDCADEBDBDCADBBCABEBADADDEEDEDCADDDABDDBDBDDE
# 207389  DCDEBAADDCECCBCCBCCECEEEDEABBDEDDDBBDCCBDDAAB
# 207390  BDEAECEDBDCABDABBBBAAAAECECEBCCCCEEBABBDDAABC
#
#                                        TX_GABARITO_CN  ... Q017 Q018 Q019  \
# 0       DABCEDEBEEBBCABEDDCBCBECDADCDAACBDCCCDBBBEBAB  ...    A    B    C
# 1       DABCEDEBEEBBCABEDDCBCBECDADCDAACBDCCCDBBBEBAB  ...    A    A    B
# 2       ADCDCDBBBECDCCDCBCBDABCAADCBEBABEEBBBCABEDEDE  ...    A    A    C
# 3       EDECABEDABCBEBACCDCBBEEBBCBDAAECDCBDCDBBBADCD  ...    A    A    B
# 4       EDECABEDABCBEBACCDCBBEEBBCBDAAECDCBDCDBBBADCD  ...    A    A    B
# ...                                               ...  ...  ...  ...  ...
# 207386  EDECABEDABCBEBACCDCBBEEBBCBDAAECDCBDCDBBBADCD  ...    A    B    B
# 207387  CDBBBCABEDEDEAAEBACCCBDABCDCBCBDECDADCDBBEEBB  ...    A    A    B
# 207388  DABCEDEBEEBBCABEDDCBCBECDADCDAACBDCCCDBBBEBAB  ...    A    B    C
# 207389  EDECABEDABCBEBACCDCBBEEBBCBDAAECDCBDCDBBBADCD  ...    A    B    C
# 207390  DABCEDEBEEBBCABEDDCBCBECDADCDAACBDCCCDBBBEBAB  ...    A    B    C
#
#        Q020 Q021 Q022 Q023 Q024 Q025 CONCEITO
# 0         A    A    E    A    B    B        C
# 1         A    B    B    A    A    A        E
# 2         A    A    E    A    B    B        C
# 3         A    A    B    A    A    A        E
# 4         A    A    D    A    A    B        D
# ...     ...  ...  ...  ...  ...  ...      ...
# 207386    A    A    B    A    A    B        E
# 207387    B    A    C    A    A    B        C
# 207388    A    B    E    B    D    B        C
# 207389    A    B    C    A    C    B        B
# 207390    A    A    D    B    C    B        D
#
# [207391 rows x 38 columns]
# C:\Users\gugat\AppData\Local\Temp\ipykernel_14964\1683257124.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_encode[col] = le.fit_transform(data_to_encode[col])
#         TP_SEXO  NO_MUNICIPIO_ESC  SG_UF_ESC  NO_MUNICIPIO_PROVA  SG_UF_PROVA  \
# 0             0              4752         22                1346           22
# 1             1              2931         18                1040           18
# 2             1              2852         19                1015           19
# 3             1              2079          5                 735            5
# 4             0              1917         25                 673           25
# ...         ...               ...        ...                 ...          ...
# 207386        0               213          8                  76            8
# 207387        0              4506          5                1569            5
# 207388        0              2145         25                 763           25
# 207389        0              1293         17                 487           17
# 207390        1              2619         25                 937           25
#
#         Q001  Q002  Q003  Q004  Q006  ...  Q017  Q018  Q019  Q020  Q021  Q022  \
# 0          2     4     0     0     7  ...     0     1     2     0     0     4
# 1          4     4     3     1     1  ...     0     0     1     0     1     1
# 2          3     2     1     1     3  ...     0     0     2     0     0     4
# 3          1     2     0     0     1  ...     0     0     1     0     0     1
# 4          3     4     3     2     3  ...     0     0     1     0     0     3
# ...      ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 207386     1     4     2     0     1  ...     0     1     1     0     0     1
# 207387     2     5     3     3     2  ...     0     0     1     1     0     2
# 207388     4     5     3     3     8  ...     0     1     2     0     1     4
# 207389     6     6     4     3    16  ...     0     1     2     0     1     2
# 207390     4     4     3     1     5  ...     0     1     2     0     0     3
#
#         Q023  Q024  Q025  CONCEITO
# 0          0     1     1         2
# 1          0     0     0         4
# 2          0     1     1         2
# 3          0     0     0         4
# 4          0     0     1         3
# ...      ...   ...   ...       ...
# 207386     0     0     1         4
# 207387     0     0     1         2
# 207388     1     3     1         2
# 207389     0     2     1         1
# 207390     1     2     1         3
#
# [207391 rows x 30 columns]

# %%
encoded_data = raw_data.copy()
for col in data_to_encode.columns:
    encoded_data[col] = data_to_encode[col]

# Remove as colunas de respostas para fazer a correlação
encoded_data = encoded_data.drop(columns=answers.columns)

# Verifica valores nulos
encoded_data.isnull().sum()
# Out:
# TP_FAIXA_ETARIA     0
# TP_SEXO             0
# TP_ESTADO_CIVIL     0
# TP_COR_RACA         0
# TP_NACIONALIDADE    0
#                    ..
# Q025                0
# ID                  0
# MF                  0
# NU_ANO              0
# CONCEITO            0
# Length: 69, dtype: int64

# %%
# Correlação entre as variáveis

import seaborn as sns
import matplotlib.pyplot as plt

# Filter only the columns with correlation higher than 0.5
corr = encoded_data.corr()
corr = corr[corr > 0.5]
corr = corr.dropna(how='all', axis=0)
corr = corr.dropna(how='all', axis=1)
plt.figure(figsize=(30,30))
sns.heatmap(corr, annot=True, fmt=".2f")
plt.show()
